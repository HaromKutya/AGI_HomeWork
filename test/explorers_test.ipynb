# %% [markdown]
# # Testing `explorers.py`

# %%
from importlib import reload
import matplotlib.pyplot as plt
import numpy as np
import sys
sys.path.append("..")

import explorers
reload(explorers)
# Out:
# <module 'explorers' from '../explorers.py'>

# %%
def plot_guess(guess, title):
    plt.plot(figsize=[6,4])
    plt.title(title)
    x = np.arange(0, 7, 1)
    plt.bar(x, guess)
    plt.xlabel("position")
    plt.ylabel("probability")

# %% [markdown]
# ## Homogenous Guess

# %%
plot_guess(explorers.get_guess_homogenous(), "Homogenous Guess")

# %% [markdown]
# ## Centroid Guess

# %%
guesser = explorers.get_guess_centroid()
plot_guess(guesser(), "Centroid Guess")
# Out:
# [  62150  605138 2418676 3826704 2419604  605395   60068]
